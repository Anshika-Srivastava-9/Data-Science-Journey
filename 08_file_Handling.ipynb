# %%
f = open("text.txt","r")

# %%
f.read()
# Out:
# 'Anshika'

# %%
s="This is nice way to learn data science"

# %%
f=open ("Anshika.txt","w")

# %%
f.write(s)
# Out:
# 38

# %%
f.close()

# %%
with open("text.txt","r")as file:
    content=file.read()
    print(content)
# Out:
# Anshika

# %%
s = "This is nice way to learn data science"
with open("Anshika.txt","w")as file:
      x=  file.write(s)
      print(x)
# Out:
# 38

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\anshi\Desktop\Data Science Course

# %%
s = "This is nice way to learn data science"

import os
print(os.getcwd())

with open("Anshika.txt", "w") as file:
    x = file.write(s)
    print("Characters written =", x)

print("Program finished successfully.")
# Out:
# C:\Users\anshi\Desktop\Data Science Course
# Characters written = 38
# Program finished successfully.

# %%
with open("Anshika.txt", "r") as file:
    print(file.read())
# Out:
# This is nice way to learn data science

# %%
import os

print(os.getcwd())
print(os.path.abspath("Anshika.txt"))
# Out:
# C:\Users\anshi\Desktop\Data Science Course
# C:\Users\anshi\Desktop\Data Science Course\Anshika.txt

# %%
import os

print(os.path.exists("Anshika.txt"))
print(os.path.getsize("Anshika.txt"))
# Out:
# True
# 38
