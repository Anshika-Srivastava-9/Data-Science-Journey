# %%
import json

# %%
data ={"name":"Alice" ,"age": 24 ,"city" :"new York"}        #  CONVERT PYTHON OBJECT TO JSON string
s=json.dumps(data)
type(s)
print(s)
# Out:
# {"name": "Alice", "age": 24, "city": "new York"}

# %%
d =json.loads('{"name":"Alice" ,"age": 24 ,"city" :"new York"}')    # CONVERT JSON string TO PYTHON OBJECT

# %%
type(d)
# Out:
# dict

# %%
file = open("data.json", "w")
json.dump(data, file)
file.close()
