# %%
name="Anshika"

# %%
print(name)
# Out:
# Anshika

# %%
name.upper()
# Out:
# 'ANSHIKA'

# %%
name.endswith("ika")
# Out:
# True

# %%
name.lower()
# Out:
# 'anshika'

# %%
s="codeWithHarry"

# %%
print(len(s))
# Out:
# 13

# %%
s[0:5]
# Out:
# 'codeW'
