# %%
code=2000

# %%
match code:
    case 200:
        print("Response ok ")
        print("Good job")
    case 400:
        print("bad response")

    case 404:
        print("Not found")

print("end of program")
# Out:
# end of program
