# %%
""" np.insert(array, index, value, axis=None) 
axis =0 ,row wise
1 column wise 
"""

import numpy as np
arr = np.array([10,20,30,40,50,60])
print(arr)
new_arr = np.insert(arr, 2, 70)
print(new_arr)
# Out:
# [10 20 30 40 50 60]
# [10 20 70 30 40 50 60]
