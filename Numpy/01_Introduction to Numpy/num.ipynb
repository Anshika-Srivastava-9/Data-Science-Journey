# %%
import numpy as np

# %%
temperature = np.array([32.5, 31.8, 33.0, 35.2, 36.6])
average = np.mean(temperature)
print(average)
# Out:
# 33.82

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.5

# %%
python_list=[1,2,3,45,4]
print(python_list)
# Out:
# [1, 2, 3, 45, 4]
