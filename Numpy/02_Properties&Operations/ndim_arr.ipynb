# %%
import numpy as np

arr1_d = np.array([1,2,3])
arr2_d = np.array([[1,2,3],[4.5,5,6]])
arr3_d = np.array([[[7,8],[9,0],[1,2],[7,3]]])

print(arr1_d.ndim)
print(arr1_d.dtype)

print(arr2_d.ndim)
print(arr2_d.dtype)

print(arr3_d.ndim)
print(arr3_d.dtype)
# Out:
# 1
# int64
# 2
# float64
# 3
# int64
