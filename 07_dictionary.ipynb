# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
student={
    "name": "Anshika",
    "age": 23,
    "grade":"a"
}

# %%
student["name"]
# Out:
# 'Anshika'

# %%
r=student.get("name2")

# %%
r

# %%
print(r)
# Out:
# None

# %%
print(student["age"])
# Out:
# 23

# %%
student["age"]=22

# %%
print(student["age"])
# Out:
# 22

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Anshika', 22, 'a'])

# %%
student.items()
# Out:
# dict_items([('name', 'Anshika'), ('age', 22), ('grade', 'a')])

# %%
student.update({"name" :"Neha"})

# %%
student
# Out:
# {'name': 'Neha', 'age': 22, 'grade': 'a'}
