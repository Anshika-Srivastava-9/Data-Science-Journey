# %%
s="Anshika"

# %%
s[0]
# Out:
# 'A'

# %%
s.upper()
# Out:
# 'ANSHIKA'

# %%
name="Anshika"
age=23
print("My name is {} and i am {} years old".format(name,age))
# Out:
# My name is Anshika and i am 23 years old

# %%
print(f"My name is {name } and i am {age} years old")
# Out:
# My name is Anshika and i am 23 years old

# %%
print(f"{'Python':<10}")
print(f"{'Python':>10}")
print(f"{'Python':^10}")
# Out:
# Python
#     Python
#   Python
