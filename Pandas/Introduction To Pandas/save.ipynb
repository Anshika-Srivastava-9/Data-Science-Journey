# %%
import pandas as pd

data = {
    "name": ["Anshika","Neha","Alfee"],
    "age": [23,22,20],
    "city": ["Lucknow","Kanpur","Delhi"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       name  age     city
# 0  Anshika   23  Lucknow
# 1     Neha   22   Kanpur
# 2    Alfee   20    Delhi

# %%
# df.to_csv("output1.csv" ,index=False)

# %%
import pandas as pd

data = {
    "name": ["Anshika","Neha","Alfee"],
    "age": [23,22,20],
    "city": ["Lucknow","Kanpur","Delhi"]
}

df = pd.DataFrame(data)
print(df)
df.to_excel("output.xlsx", index=False)
# Out:
#       name  age     city
# 0  Anshika   23  Lucknow
# 1     Neha   22   Kanpur
# 2    Alfee   20    Delhi

# %%
import pandas as pd
data = {
    "name": ["Anshika","Neha","Alfee"],
    "age": [23,22,20],
    "city": ["Lucknow","Kanpur","Delhi"]
}

df = pd.DataFrame(data)
df.to_json("output.json")
