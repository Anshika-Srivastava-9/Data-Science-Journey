# %%
import pandas as pd 
data = {
    'name':['Arnav','Rudransh','Ayansh','Pratyush','Snehal'],
    'age':[23,24,26,25,29],
    'salary':[20000,45000,60000,34000,69000],
    'performance_score':[10,30,60,20,40]
}
df =pd.DataFrame(data)

df.loc[0,'name']= 'Pranav'
print(df)
# Out:
#        name  age  salary  performance_score
# 0    Pranav   23   20000                 10
# 1  Rudransh   24   45000                 30
# 2    Ayansh   26   60000                 60
# 3  Pratyush   25   34000                 20
# 4    Snehal   29   69000                 40

# %%
df['salary']=df['salary']*0.05
print(df)
# Out:
#        name  age  salary  performance_score
# 0    Pranav   23  1000.0                 10
# 1  Rudransh   24  2250.0                 30
# 2    Ayansh   26  3000.0                 60
# 3  Pratyush   25  1700.0                 20
# 4    Snehal   29  3450.0                 40
