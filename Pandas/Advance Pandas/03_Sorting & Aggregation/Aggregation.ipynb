# %%
# this give mean min max sum these type of values 
# like :
# df.mean()
# df.min()
# df.max()
# df.sum()
# df.average()

import pandas as pd 
data = {
    'name':['Karan','Taran','Aman'],
    'age':[25,29,22],
    'score':[30,29,25]
}
df= pd.DataFrame(data)
print(df)

avegare_score= df['score'].mean()
print(avegare_score)
# Out:
#     name  age  score
# 0  Karan   25     30
# 1  Taran   29     29
# 2   Aman   22     25
# 28.0

# %%
sum=30+29+25
print(sum/3)
# Out:
# 28.0
