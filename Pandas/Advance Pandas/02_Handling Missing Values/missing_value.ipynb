# %%
import pandas as pd 
data = {
    'name':['Arnav',None,'Rudransh','Ayansh','Pratyush','Snehal'],
    'age':[23,None,24,26,25,29],
    'salary':[20000,None,45000,60000,34000,69000],
    'performance_score':[10,None,30,60,20,40]
}
df =pd.DataFrame(data)
# print(df)
print(df.isnull().sum())
# Out:
# name                 1
# age                  1
# salary               1
# performance_score    1
# dtype: int64
