# %%
# Step 1 :Sample data frame
import pandas as pd 
data={
    "name":['Anshika' , 'Neha', 'Alfee', 'Vidhi','Angel'],
    "age":[22,22,20,14,15],
    "city":['LKO','Kanpur','Bihar','SultanPur','Delhi'],
    "Salary":[1800000,200000,230000,7800000,400000],
    "Performance Score":[98,99,94,96,97]
}
df=pd.DataFrame(data)

# %%
print("sample dataframe")
print(df)
# Out:
# sample dataframe
#       name  age       city   Salary  Performance Score
# 0  Anshika   22        LKO  1800000                 98
# 1     Neha   22     Kanpur   200000                 99
# 2    Alfee   20      Bihar   230000                 94
# 3    Vidhi   14  SultanPur  7800000                 96
# 4    Angel   15      Delhi   400000                 97

# %%
print("Descriptive Statistics")
print(df.describe())
# Out:
# Descriptive Statistics
#              age        Salary  Performance Score
# count   5.000000  5.000000e+00           5.000000
# mean   18.600000  2.086000e+06          96.800000
# std     3.847077  3.262511e+06           1.923538
# min    14.000000  2.000000e+05          94.000000
# 25%    15.000000  2.300000e+05          96.000000
# 50%    20.000000  4.000000e+05          97.000000
# 75%    22.000000  1.800000e+06          98.000000
# max    22.000000  7.800000e+06          99.000000
