# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\anshi\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\anshi\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anshi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anshi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anshi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\anshi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\anshi\Downloads\tested-selected-columns.csv")

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare
# 0                330911    7.8292
# 1                363272    7.0000
# 2                240276    9.6875
# 3                315154    8.6625
# 4               3101298   12.2875
# ..                  ...       ...
# 413           A.5. 3236    8.0500
# 414            PC 17758  108.9000
# 415  SOTON/O.Q. 3101262    7.2500
# 416              359309    8.0500
# 417                2668   22.3583
#
# [418 rows x 10 columns]

# %%
df=pd.read_excel(r"C:\Users\anshi\Downloads\sample_data.xlsx")

# %%
print(df)
# Out:
#     ID     Name   Department  Salary  Experience
# 0  101  Anshika           AI   65000           2
# 1  102    Rahul           HR   45000           4
# 2  103    Priya      Finance   55000           3
# 3  104     Aman  Development   70000           5
# 4  105    Sneha    Marketing   50000           2

# %%
import json
import pandas as pd

with open("data.json", "r") as f:
    data = json.load(f)

df = pd.DataFrame([data])
print(df)
# Out:
#     name  age      city
# 0  Alice   24  new York
