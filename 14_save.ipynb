# %%
import pandas as pd

# %%
data={
    "Name" :['Ram' ,'Shyam', 'Ghanshyam'],
    "Age" :[20,23,22],
    "city":['lko','Delhi','Agra']
}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#         Name  Age   city
# 0        Ram   20    lko
# 1      Shyam   23  Delhi
# 2  Ghanshyam   22   Agra

# %%
df.to_csv("output.csv",index=False)

# %%
print(df)
# Out:
#         Name  Age   city
# 0        Ram   20    lko
# 1      Shyam   23  Delhi
# 2  Ghanshyam   22   Agra

# %%
import pandas as pd

df = pd.read_excel("output.xlsx")
print(df)
# Out:
#         Name  Age   city
# 0        Ram   20    lko
# 1      Shyam   23  Delhi
# 2  Ghanshyam   22   Agra

# %%
# head() tail()
#head(n)  n pass kenege to starting ki n row degna agr nhi pass krnege n to stating 5 row dega
#tail(n)  last ki n row similarly as head()

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\anshi\Downloads\tested-selected-columns.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare
# 0   330911   7.8292
# 1   363272   7.0000
# 2   240276   9.6875
# 3   315154   8.6625
# 4  3101298  12.2875

# %%
print("Display 2 rows of head")
df.head(2)
# Out:
# Display 2 rows of head
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare
# 0  34.5      0      0  330911  7.8292
# 1  47.0      1      0  363272  7.0000

# %%
print("Display 2 rows of tail")
df.tail()
# Out:
# Display 2 rows of tail
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare
# 413   NaN      0      0           A.5. 3236    8.0500
# 414  39.0      0      0            PC 17758  108.9000
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500
# 416   NaN      0      0              359309    8.0500
# 417   NaN      1      1                2668   22.3583
