# %%
a={}

# %%
type(a)
# Out:
# dict

# %%
b=set()

# %%
type(b)
# Out:
# set

# %%
s={3,2,45,65,76,54,34,45}

# %%
s
# Out:
# {2, 3, 34, 45, 54, 65, 76}

# %%
set=([1,2,3,4])

# %%
s1={1,2,3,4}
s2={3,4,5,6}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.intersection(s2)
# Out:
# {3, 4}

# %%
sub={1,2}

# %%
sub.issubset(s1)
# Out:
# True

# %%
s1.issuperset(sub)
# Out:
# True
